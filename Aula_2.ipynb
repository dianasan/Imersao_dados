# %% [markdown]
# <a href="https://colab.research.google.com/github/dianasan/Imersao_dados/blob/main/Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imersão dados 4 Alura **

# %% [markdown]
# Importamos a biblioteca pandas, colocamos o do url dataframe que será lido e depois chamamos a função que lê os dados

# %%
import pandas as pd 
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %% [markdown]
# Função que mostra as 5 primeiras linhas

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %% [markdown]
# Essa função pega uma amostra aleatória dos dados, nesse caso 15

# %%
dados.sample(15)
# Out:
#                                   Rua                      Bairro     Cidade  \
# 3710               Rua Nicolau Zarvos            Parque Jabaquara  São Paulo
# 9398                   Rua Itabaquara                    Pacaembu  São Paulo
# 3285     Rua Bernardino de Campos, 0                   Campo Belo  São Paulo
# 5541              Rua França Carvalho               Alto da Mooca  São Paulo
# 7772           Rua Pierre de Beranger                Campo Grande  São Paulo
# 2953              Rua Francisco Farel        Jardim das Bandeiras  São Paulo
# 6017                              NaN                 Santo Amaro  São Paulo
# 3020                   Rua Costa Rica              Jardim América  São Paulo
# 2167                              NaN                Alto da Lapa  São Paulo
# 6737         Avenida dos Bandeirantes           Planalto Paulista  São Paulo
# 4179  Avenida Doutor Alberto Penteado  Jardim Sílvia (Zona Oeste)  São Paulo
# ...

# %% [markdown]
# Essa função mostra algumas informações como os nomes das colunas, quantas linhas tem valores e os tipos de cada dado

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %% [markdown]
# Usando essa estrutura descobrimos qual informação está na linha 6081 da coluna "Bairro"

# %%
dados["Bairro"][6081]
# Out:
# 'Chácara Inglesa'

# %% [markdown]
# Para saber a média dos valores de uma dada coluna temos duas opções: colocar o nome da coluna entre colchetes ou entre pontos e chamar a função mean()

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
dados.Banheiros.mean()
# Out:
# 3.8790967226219024

# %% [markdown]
# Essa função soma quantas linhas da coluna tem o nome procurado, nesse caso, o nome Pinheiros na coluna Bairro

# %%
sum((dados["Bairro"] == "Pinheiros"))
# Out:
# 99

# %% [markdown]
# Criamos uma variável e usamos ela para saber se o valor buscado existe em determinada coluna. Se o retorno for false o valor gravado naquela linha não é igual ao desejado

# %%
tem_imoveis_pin = (dados["Bairro"] == "Pinheiros")
tem_imoveis_pin
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %% [markdown]
# Aqui criamos uma variável para exibir algumas das linhas que possuem o valor desejado, nesse caso as linhas que tem como bairro "Pinheiros"

# %%
imoveis_pin = dados[tem_imoveis_pin]
imoveis_pin
# Out:
#                               Rua     Bairro     Cidade  Metragem  Quartos  \
# 578                           NaN  Pinheiros  São Paulo       130        1
# 645            Rua Capote Valente  Pinheiros  São Paulo       180        3
# 648         Rua Sílvio Sacramento  Pinheiros  São Paulo       100        3
# 680        Rua Miranda Montenegro  Pinheiros  São Paulo       460        4
# 866   Rua Cardeal Arcoverde, 353   Pinheiros  São Paulo       130        4
# ...                           ...        ...        ...       ...      ...
# 9168             Rua Oscar Freire  Pinheiros  São Paulo       800        1
# 9340                          NaN  Pinheiros  São Paulo       205        2
# 9566                          NaN  Pinheiros  São Paulo       420        4
# 9693                          NaN  Pinheiros  São Paulo       425        4
# 9729                          NaN  Pinheiros  São Paulo       425        4
#
#       Banheiros  Vagas                                 Valor
# ...

# %% [markdown]
# Desafio 1  - Realizar a média da metragem para cada um dos bairros

# %%
media_bairros = dados.groupby("Bairro").Metragem.mean()
media_bairros
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
media_bairros.head(10).plot.bar()

# %% [markdown]
# Desafio 2 - Outras formas de selecionar os dados por bairro

# %%
dados.query("Bairro == 'Vila Mariana'")
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
dados.loc[dados['Bairro'] == 'Brooklin Paulista']
# Out:
#                                          Rua             Bairro     Cidade  \
# 50                                Rua Kansas  Brooklin Paulista  São Paulo
# 104                                      NaN  Brooklin Paulista  São Paulo
# 122                        Rua Kansas, 1326   Brooklin Paulista  São Paulo
# 135                              Rua Laplace  Brooklin Paulista  São Paulo
# 284                               Rua Kansas  Brooklin Paulista  São Paulo
# ...                                      ...                ...        ...
# 9950                           Rua Luisiania  Brooklin Paulista  São Paulo
# 9952                     Rua Princesa Isabel  Brooklin Paulista  São Paulo
# 9978  Rua Professor Miguel Maurício da Rocha  Brooklin Paulista  São Paulo
# 9986                           Rua Luisiania  Brooklin Paulista  São Paulo
# 9988                     Rua Princesa Isabel  Brooklin Paulista  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# ...

# %%
dados.loc[8][1]
# Out:
# 'Jardim Benfica'

# %% [markdown]
# Desafio 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(20).plot.bar()

# %% [markdown]
# Os bairros com mais casas disponíveis tem uma média de aproximadamente 400 imóveis e aparentemente são em uma área nobre.

# %%
n_banheiros_imo = dados["Banheiros"].value_counts()
n_banheiros_imo.head(10).plot.bar()

# %% [markdown]
# A maior parte dos imóveis disponíveis tem entre 3 e 4 banheiros, poucos imóveis destoam e possuem mais de 8 banheiros.

# %%
n_quartos_imo = dados["Quartos"].value_counts()
n_quartos_imo.head(10).plot.bar()

# %% [markdown]
# A maior parte dos imóveis tem cerca de 3 a 4 quartos, um número muito baixo dos imóveis possuem mais de 9 quartos.

# %%
n_vagas_imo = dados["Vagas"].value_counts()
n_vagas_imo.head(10).plot.pie()

# %% [markdown]
# A maior parte dos imóveis possuem entre 2 e 4 vagas, um núnmero muito pequeno dos imóveis possui mais de 10 vagas

# %% [markdown]
# Desafio 4 - Pegar outras estatísticas dos dados, média, mediana, min, max

# %% [markdown]
# Essa função coloca todos esses valores em uma tabela, além de colocar os valores dos quartis

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %% [markdown]
# Essa função mostra quantas vezes determinado valor aparece na coluna e coloca eles em ordem decrescente

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
dados["Quartos"].value_counts()
# Out:
# 3     4213
# 4     3309
# 2     1195
# 5      859
# 6      217
# 1      107
# 7       56
# 8       20
# 9       12
# 10       8
# 11       6
# 12       2
# 16       2
# 13       1
# 15       1
# Name: Quartos, dtype: int64

# %%
dados["Vagas"].value_counts()
# Out:
# 2     2380
# 4     2117
# 3     1564
# 6     1068
# 5      879
# 1      800
# 8      435
# 10     282
# 7      238
# 12      67
# 9       57
# 15      25
# 14      25
# 11      14
# 20      13
# 16       9
# 13       6
# 30       6
# 25       5
# 18       5
# 26       3
# 24       2
# 40       2
# 50       2
# 38       1
# 42       1
# 34       1
# 23       1
# Name: Vagas, dtype: int64

# %%
dados["Banheiros"].value_counts()
# Out:
# 3     1952
# 4     1838
# 2     1632
# 5     1615
# 6     1037
# 1     1034
# 7      488
# 8      284
# 9       62
# 10      36
# 11      15
# 12       8
# 14       4
# 40       2
# 16       1
# Name: Banheiros, dtype: int64

# %% [markdown]
# Média da metragem

# %%
imoveis_pin["Metragem"].mean()
# Out:
# 305.4040404040404

# %%
dados.Metragem.max()
# Out:
# 750000

# %%
dados.Metragem.min()
# Out:
# 10

# %%
dados.Quartos.max()
# Out:
# 16

# %%
dados.Quartos.min()
# Out:
# 1

# %%
dados.Banheiros.max()
# Out:
# 40

# %%
dados.Banheiros.min()
# Out:
# 1

# %%
dados.Vagas.max()
# Out:
# 50

# %%
dados.Vagas.min()
# Out:
# 1

# %% [markdown]
# Desafio 5 - Descobrir quais são os bairros que não tem nome de rua

# %%
dados.isnull().sum()
# Out:
# Rua          3434
# Bairro         12
# Cidade          0
# Metragem        0
# Quartos         0
# Banheiros       0
# Vagas           0
# Valor           0
# dtype: int64

# %%
ruas_snome = dados["Rua"].isnull()
dados[ruas_snome]
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor
# 3             2      4    R$ 685.000
# ...

# %%
dados[dados['Bairro'].isna()]
# Out:
#                                               Rua Bairro     Cidade  Metragem  \
# 7263                 Rua Madalena de Morais, 3773    NaN  São Paulo       742
# 7956                                Rua Vergueiro    NaN  São Paulo       103
# 7996                    Rua Alvorada do Sul, 3773    NaN  São Paulo       678
# 8126         Rua Professor Eduardo Monteiro, 3773    NaN  São Paulo       550
# 8566          Avenida Comendador Adibo Ares, 3773    NaN  São Paulo       694
# 8619                    Rua Alvorada do Sul, 3773    NaN  São Paulo       683
# 8739                    Rua Alvorada do Sul, 3773    NaN  São Paulo       683
# 8868         Rua Professor Eduardo Monteiro, 3773    NaN  São Paulo       555
# 8943                      Rua Santo Eufredo, 3773    NaN  São Paulo       846
# 8992         Rua Professor Eduardo Monteiro, 3773    NaN  São Paulo       555
# 9310  Rua Professor Lúcio Martins Rodrigues, 3773    NaN  São Paulo       358
# ...

# %% [markdown]
# Aula 2

# %% [markdown]
# Fazendo a limpeza dos dados para conseguir transformar a coluna "Valor" que é uma string em um float usando a função split

# %%
dados.Valor
# Out:
# 0                                R$ 7.000.000
# 1                                R$ 3.700.000
# 2                                  R$ 380.000
# 3                                  R$ 685.000
# 4                                  R$ 540.000
#                          ...
# 10003                              R$ 665.000
# 10004                            R$ 2.300.000
# 10005                            R$ 1.050.000
# 10006    R$ 2.200\n                      /Mês
# 10007                              R$ 270.000
# Name: Valor, Length: 10008, dtype: object

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
len(dados["Valor"].str.split(expand = True)[1].unique())
# Out:
# 1038

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %% [markdown]
# Adicionando novas colunas no dataset.
# Atenção: Se você nomear a nova coluna como uma coluna já existente no dataset essa coluna será sobrescrita com os novos valores

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %% [markdown]
# Usamos a função drop para excluir a coluna, por isso o axis=1 e o inplace=True é para informar que estamos excluindo do dataframe original

# %%
dados.drop(["Valor"], axis = 1, inplace = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6    R$     7.000.000         None
# 1        4          4      4    R$     3.700.000         None
# 2        4          3      2    R$       380.000         None
# 3        3          2      4    R$       685.000         None
# 4        3          2      2    R$       540.000         None

# %%
dados[dados["Tipo_anuncio"].isnull()]["Tipo_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %% [markdown]
# Filtrando os valores de aulguel do conjunto de dados, reduzimos de 10008 para 9156. Repare que aqui já não trabalhamos mais com o dados e sim com dados_vendas

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas Moeda Valor_anuncio Tipo_anuncio
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Moeda          9156 non-null   object
#  8   Valor_anuncio  9156 non-null   object
#  9   Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(6)
# memory usage: 786.8+ KB

# %% [markdown]
# Apesar de ter separado a string de valor em 3 colunas diferentes a coluna "Valor_anuncio" ainda não é float usamos a função replace para transformar a coluna

# %%
dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# ...

# %%
dados_vendas['Valor_anuncio'] = dados_vendas['Valor_anuncio_float']
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas Moeda  Valor_anuncio Tipo_anuncio  \
# ...

# %% [markdown]
# Excluimos a coluna "Valor_anuncio_float" agora que já temos a coluna "Valor_anuncio" com o tipo float

# %%
dados_vendas.drop(["Valor_anuncio_float"], axis = 1, inplace = True)
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas Moeda  Valor_anuncio Tipo_anuncio
# 0        4          8      6    R$      7000000.0         None
# 1        4          4      4    R$      3700000.0         None
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Moeda          9156 non-null   object
#  8   Valor_anuncio  9156 non-null   float64
#  9   Tipo_anuncio   0 non-null      object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 786.8+ KB

# %%
dados_vendas["Valor_anuncio"].plot.hist(bins = 50)

# %% [markdown]
# Aqui limitamos a precisão dos valores

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio
# count   9156.00  9156.00    9156.00 9156.00        9156.00
# mean     434.42     3.45       3.80    3.96     3052202.96
# std     7856.42     1.05       1.97    2.60     3944208.19
# min       10.00     1.00       1.00    1.00       13000.00
# 25%      168.00     3.00       2.00    2.00      890000.00
# 50%      276.00     3.00       4.00    4.00     1800000.00
# 75%      450.00     4.00       5.00    5.00     3500000.00
# max   750000.00    16.00      40.00   50.00    65000000.00

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
sns.set()
plt.figure(figsize=(10,8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio", kde = True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# Desafio 1 - Criar uma escala de valores em milhões

# %%
dados_vendas_escala = dados[dados['Tipo_anuncio'].isnull()]
dados_vendas_escala.head(10)
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 5                 Rua Graham Bell         Santo Amaro  São Paulo       440
# 6        Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
# 7     Rua Guilherme Valente, 150     Jardim Vergueiro  São Paulo       150
# 8         Rua Sagrada Família, 8       Jardim Benfica  São Paulo        48
# 9                      Rua Tapaji         Vila Alpina  São Paulo       114
#
#    Quartos  Banheiros  Vagas Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6    R$     7.000.000         None
# ...

# %%
dados_vendas_escala['Valor_milhoes'] = dados_vendas['Valor_anuncio']/1000000
dados_vendas_escala.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas Moeda Valor_anuncio Tipo_anuncio  Valor_milhoes
# ...

# %% [markdown]
# Desafio 2 - Melhorar a visualização do histograma

# %%
dados_vendas_escala['Valor_milhoes'].plot.hist()

# %%
sns.set()
plt.figure(figsize=(17,7))
sns.color_palette("Paired")
plot = sns.histplot(data=dados_vendas_escala, x='Valor_milhoes', kde=True, shrink=.8)

plt.suptitle('Histograma de Valor do Imóvel na Cidade de SP')
plt.title('Valores entre 0 e 15 milhões')
plt.xlabel('Valor do Imóvel')
plt.ylabel('Quantidade de Imóveis à Venda')

plot.legend(['Valores em escala de milhão'], prop={'size': 20})

plt.xlim((-1, 15))

plt.show()

# %% [markdown]
# Desafio 3 - Preço do metro quadrado por bairro e plotar o gráfico ideal

# %%
dados_vendas_escala.groupby('Bairro').mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_milhoes
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1.76
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2.39
# Alto da Lapa         299.25     3.15       3.85   4.00           2.08
# Alto da Mooca        270.05     3.30       2.60   3.65           1.18
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4.78
# ...                     ...      ...        ...    ...            ...
# Vila Água Funda      152.20     2.60       2.20   2.60           0.65
# Água Branca          173.58     3.08       3.25   2.25           1.23
# Água Fria            165.42     2.83       3.42   2.50           0.93
# Água Funda           139.00     3.00       2.50   2.00           0.55
# Água Rasa            186.17     2.67       2.00   3.67           0.72
#
# [697 rows x 5 columns]

# %%
dados_vendas_escala['Valor_m2'] = dados_vendas['Valor_anuncio']/dados_vendas['Metragem']
dados_bairro_valor_m2 = dados_vendas_escala.groupby(['Bairro']).mean()
dados_bairro_valor_m2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    Metragem  Quartos  Banheiros  Vagas  Valor_milhoes  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1.76
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2.39
# Alto da Lapa         299.25     3.15       3.85   4.00           2.08
# Alto da Mooca        270.05     3.30       2.60   3.65           1.18
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4.78
# ...                     ...      ...        ...    ...            ...
# Vila Água Funda      152.20     2.60       2.20   2.60           0.65
# ...

# %% [markdown]
# Aqui separamos apenas os 20 bairros com o M² mais caro com a função nlargest que passa a quantidade e a coluna e depois plotamos o grfáfico. Depois temos uma outra forma de fazer a mesma coisa (identificar os 20 bairros com o M² mais caro e plotar o gráfico)

# %%
top20 = dados_bairro_valor_m2.nlargest(20,'Valor_m2')
top20
# Out:
#                       Metragem  Quartos  Banheiros  Vagas  Valor_milhoes  \
# Bairro
# Vila Guaca               10.00     3.00       2.00   2.00           0.80
# Jardim América          646.31     4.04       5.08   7.13          16.43
# Jardim Ampliação         91.67     3.00       3.00   2.50           0.83
# Jardim Europa           566.18     3.79       4.73   5.03          11.50
# Vila Nova Conceição     299.32     2.98       3.38   3.24           5.26
# Jardim Teresa           648.33     5.00       6.00   6.00          14.84
# Jardim Luzitânia        499.10     3.53       4.91   4.32           8.47
# Jardim Paulista         489.79     3.86       4.63   4.40           8.03
# Jardim Paulistano       384.09     3.69       4.04   3.95           5.73
# Itaim Bibi              161.70     2.52       2.70   1.96           2.17
# Jardim Luanda           112.50     3.00       2.00   3.00           1.40
# Vila Olímpia            194.35     2.97       3.27   2.24           2.38
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=top20, x='Valor_m2', y='Bairro')

# %%
precos_m2 = dados_vendas_escala.groupby("Bairro")["Valor_m2"].mean().sort_values(ascending=False)
precos_m2
# Out:
# Bairro
# Vila Guaca                     80000.00
# Jardim América                 24088.57
# Jardim Ampliação               20051.04
# Jardim Europa                  19962.69
# Vila Nova Conceição            17614.03
#                                  ...
# Jardim Brasília (Zona Leste)    1055.01
# Jardim Itapemirim               1054.50
# Vila Aurea                       906.59
# Jardim Vera Cruz(Zona Leste)     544.76
# Sítio Represa                     78.38
# Name: Valor_m2, Length: 697, dtype: float64

# %%
plt.figure(figsize=(15,5))

ax = precos_m2.head(20).plot.bar()
ax.get_yaxis().set_major_formatter(plt.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

plt.title("Preço dos M² mais caros (Top 20 Bairros)", fontsize=26, fontweight="bold")
plt.xlabel("Bairro", fontsize=20, fontweight="bold")
plt.ylabel("Preço do M² (R$)", fontsize=20, fontweight="bold")
plt.tick_params(axis='both', which='major', labelsize=14)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-8969f021b5fa> in <module>
#       2
#       3 ax = precos_m2.head(20).plot.bar()
# ----> 4 ax.get_yaxis().set_major_formatter(plt.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#       5
#       6 plt.title("Preço dos M² mais caros (Top 20 Bairros)", fontsize=26, fontweight="bold")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ticker'

# %% [markdown]
# Deafio 4 - Explorar as bibliotecas de visualizações e colocar as suas conclusões

# %%
import numpy as np

# %%
plt.figure(figsize=(10,7))

dados_vendas = dados_vendas[:200]
sns.histplot(dados_vendas, x="Quartos", y="Banheiros")

plt.show()

# %% [markdown]
# Podemos notar uma ligação entre a quantidade de banheiros e quartos de um imóvel, quanto mais quartos um imóvel possui maior a quantidade de banheiros

# %%
plt.figure(figsize=(10,7))

bathrooms = 2
dados_vendas_escala = dados_vendas_escala.query("Banheiros <= 2")
sns.displot(dados_vendas_escala, x="Quartos", y="Vagas", col="Banheiros")

plt.show()

# %% [markdown]
# Aqui vemos que as casas com 1 e 2 banheiros possuem uma quantidade similar de quartos e vagas, entre 2 e 4

# %% [markdown]
# Desafio 5 - Pesquisar uma visualização para analisar os quartis, mediana e outliers

# %%
numericos = dados_vendas_escala[['Metragem', 'Quartos', 'Banheiros', 'Vagas', 'Valor_milhoes']]

# %% [markdown]
# Primeiro calculamos as medidas separatrizes para segregar os outliers e depois filtramos o dataset para eliminar os outliers

# %%
Q1_dados = numericos.quantile(.25)
Q3_dados = numericos.quantile(.75)
IIQ_dados = Q3_dados-Q1_dados
limite_inferior_dados = Q1_dados - 1.5 * IIQ_dados
limite_superior_dados = Q3_dados + 1.5 * IIQ_dados

# %%
selecao = (numericos >= limite_inferior_dados) & (numericos <= limite_superior_dados)

dados_new = dados_vendas_escala[selecao]

# %% [markdown]
# Plotando os gráficos com e sem os outliers

# %%
for i in numericos:
  f, axes = plt.subplots(1, 2)
  f.suptitle(i + ' com Outliers e ' + i + ' sem Outliers')
  sns.boxplot(  x= i, data=dados_vendas_escala, ax=axes[0])
  sns.boxplot(  x= i, data=dados_new, ax=axes[1])  

print()
